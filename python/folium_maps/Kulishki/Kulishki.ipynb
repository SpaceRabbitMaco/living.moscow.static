# %%
import folium
from folium import plugins
from folium.plugins import MiniMap

import sys
sys.path.append('../../tools')

import MapTools as mt

# %%
# Define vars

areas = mt.load_areas('./static_data/areas/')

attractions = mt.load_markers('./static_data/markers/attractions/')
parks = mt.load_markers('./static_data/markers/parks/')
business = mt.load_markers('./static_data/markers/business/')
museums = mt.load_markers('./static_data/markers/museums/')
wcs = mt.load_markers('./static_data/markers/wcs/')

names = ['Кулишки (Ивановская горка)',]

styles = [{'fillColor':'#223e8b','color':'#223e8b','opacity':0.5},{'fillColor':'#228b82','color':'#228b82','opacity':0.5},
         {'fillColor':'#228B22','color':'#228B22','opacity':0.5},{'fillColor':'#8b2222','color':'#8b2222','opacity':0.5},
         {'fillColor':'#228b82','color':'#228b82','opacity':0.5},{'fillColor':'#8b2282','color':'#8b2282','opacity':0.5},
         {'fillColor':'#50228b','color':'#50228b','opacity':0.5},{'fillColor':'#8b5c22','color':'#8b5c22','opacity':0.5},
         {'fillColor':'#aba505','color':'#aba505','opacity':0.5},{'fillColor':'#228B22','color':'#228B22','opacity':0.5}]

# %%
# Set Kulishki start location
m = folium.Map(location=[55.755018, 37.641317],
    tiles='Stamen Toner',
    zoom_start=16,
    attributionControl=False)

# Add areas to Map   
mt.add_areas_to_map(areas, names, styles, m)

# Add minimap to Map
minimap = MiniMap(tile_layer='Stamen Toner')
m.add_child(minimap)

# Add markers on groups
fg = folium.FeatureGroup(control=False)  # Main group
g1 = folium.plugins.FeatureGroupSubGroup(fg, 'Интересные места')
g2 = folium.plugins.FeatureGroupSubGroup(fg, 'Парки')
g3 = folium.plugins.FeatureGroupSubGroup(fg, 'Кафе и Магазины')
g4 = folium.plugins.FeatureGroupSubGroup(fg, 'Музеи, Театры, Выставки')
g5 = folium.plugins.FeatureGroupSubGroup(fg, 'Туалеты (WC)')

m.add_child(fg)
m.add_child(g1)
m.add_child(g2)
m.add_child(g3)
m.add_child(g4)
m.add_child(g5)

# Add markers on Map
mt.add_markers_to_map(attractions, g1)
mt.add_markers_to_map(parks, g2)
mt.add_markers_to_map(business, g3)
mt.add_markers_to_map(museums, g4)
mt.add_markers_to_map(wcs, g5)

# Add Layer Control & Tools
folium.LayerControl().add_to(m)
plugins.Fullscreen(position='topright').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save("index.html")
